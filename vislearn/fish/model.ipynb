# %%
data_dir = 'C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\'
#show folder names
import os
os.listdir(data_dir)
# Out:
# ['Black Sea Sprat',
#  'Gilt-Head Bream',
#  'Hourse Mackerel',
#  'license.txt',
#  'README.txt',
#  'Red Mullet',
#  'Red Sea Bream',
#  'Sea Bass',
#  'Segmentation_example_script.m',
#  'Shrimp',
#  'Striped Red Mullet',
#  'Trout']

# %%
#Black Sea Sprat and its images with masks
black_sea_sprat_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Black Sea Sprat\\Black Sea Sprat"
black_sea_sprat_mask_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Black Sea Sprat\\Black Sea Sprat GT"
#show all files in black_sea_sprat_dir
black_sea_sprat_files = os.listdir(black_sea_sprat_dir)
black_sea_sprat_mask_files = os.listdir(black_sea_sprat_mask_dir)
print("Black Sea Sprat files:")
print(black_sea_sprat_files)
print("Black Sea Sprat mask files:")
print(black_sea_sprat_mask_files)
#Gilt-Head Bream
gilthead_bream_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Gilt-Head Bream\\Gilt-Head Bream"
gilthead_bream_mask_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Gilt-Head Bream\\Gilt-Head Bream GT"
#Hourse Mackerel
horse_mackerel_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Hourse Mackerel\\Hourse Mackerel"
horse_mackerel_mask_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Hourse Mackerel\\Hourse Mackerel GT"
#Red Mullet
red_mullet_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Red Mullet\\Red Mullet"
red_mullet_mask_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Red Mullet\\Red Mullet GT"
#Red Sea Bream
red_sea_bream_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Red Sea Bream\\Red Sea Bream"
red_sea_bream_mask_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Red Sea Bream\\Red Sea Bream GT"
#Sea Bass
sea_bass_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Sea Bass\\Sea Bass"
sea_bass_mask_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Sea Bass\\Sea Bass GT"
#Shrimp
shrimp_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Shrimp\\Shrimp"
shrimp_mask_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Shrimp\\Shrimp GT"
#Striped Red Mullet
striped_red_mullet_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Striped Red Mullet\\Striped Red Mullet"
striped_red_mullet_mask_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Striped Red Mullet\\Striped Red Mullet GT"
#Trout
trout_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Trout\\Trout"
trout_mask_dir = "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Trout\\Trout GT"
# Out:
# Black Sea Sprat files:
# ...

# %%
import glob

def list_files_in_directory(directory):
    return os.listdir(directory)

fish_species = {
    "Black Sea Sprat": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Black Sea Sprat\\Black Sea Sprat",
    "Gilt-Head Bream": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Gilt-Head Bream\\Gilt-Head Bream",
    "Hourse Mackerel": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Hourse Mackerel\\Hourse Mackerel",
    "Red Mullet": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Red Mullet\\Red Mullet",
    "Red Sea Bream": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Red Sea Bream\\Red Sea Bream",
    "Sea Bass": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Sea Bass\\Sea Bass",
    "Shrimp": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Shrimp\\Shrimp",
    "Striped Red Mullet": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Striped Red Mullet\\Striped Red Mullet",
    "Trout": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Trout\\Trout"
}

fish_species_mask = {
    "Black Sea Sprat mask": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Black Sea Sprat\\Black Sea Sprat GT",
    "Gilt-Head Bream mask": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Gilt-Head Bream\\Gilt-Head Bream GT",
    "Hourse Mackerel mask": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Hourse Mackerel\\Hourse Mackerel GT",
    "Red Mullet mask": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Red Mullet\\Red Mullet GT",
    "Red Sea Bream mask": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Red Sea Bream\\Red Sea Bream GT",
    "Sea Bass mask": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Sea Bass\\Sea Bass GT",
    "Shrimp mask": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Shrimp\\Shrimp GT",
    "Striped Red Mullet mask": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Striped Red Mullet\\Striped Red Mullet GT",
    "Trout mask": "C:\\projects\\all-projects\\vislearn\\fish\\Fish_Dataset\\Trout\\Trout GT"
}

# %%
for fish, dir_path in fish_species.items():
    files = list_files_in_directory(dir_path)
    print(f"{fish} files:")
    print(files)
# Out:
# Black Sea Sprat files:
# ...

# %%
for fish, dir_path in fish_species_mask.items():
    masks = list_files_in_directory(dir_path)
    print(f"{masks} files:")
    print(masks)
# Out:
# ['00001.png', '00002.png', '00003.png', '00004.png', '00005.png', '00006.png', '00007.png', '00008.png', '00009.png', '00010.png', '00011.png', '00012.png', '00013.png', '00014.png', '00015.png', '00016.png', '00017.png', '00018.png', '00019.png', '00020.png', '00021.png', '00022.png', '00023.png', '00024.png', '00025.png', '00026.png', '00027.png', '00028.png', '00029.png', '00030.png', '00031.png', '00032.png', '00033.png', '00034.png', '00035.png', '00036.png', '00037.png', '00038.png', '00039.png', '00040.png', '00041.png', '00042.png', '00043.png', '00044.png', '00045.png', '00046.png', '00047.png', '00048.png', '00049.png', '00050.png', '00051.png', '00052.png', '00053.png', '00054.png', '00055.png', '00056.png', '00057.png', '00058.png', '00059.png', '00060.png', '00061.png', '00062.png', '00063.png', '00064.png', '00065.png', '00066.png', '00067.png', '00068.png', '00069.png', '00070.png', '00071.png', '00072.png', '00073.png', '00074.png', '00075.png', '00076.png', '00077.pn
# ...

# %%
#create two dataframes for fish images and their masks
import pandas as pd
fish_df = pd.DataFrame(columns=["fish", "file_name"])
fish_mask_df = pd.DataFrame(columns=["fish", "file_name"])

for fish, dir_path in fish_species.items():
    files = list_files_in_directory(dir_path)
    fish_df = pd.concat([fish_df, pd.DataFrame({"fish": [fish]*len(files), "file_name": files})], ignore_index=True)

for fish, dir_path in fish_species_mask.items():
    files = list_files_in_directory(dir_path)
    fish_mask_df = pd.concat([fish_mask_df, pd.DataFrame({"fish": [fish]*len(files), "file_name": files})], ignore_index=True)

# %%
fish_df.head()
# Out:
#               fish  file_name
# 0  Black Sea Sprat  00001.png
# 1  Black Sea Sprat  00002.png
# 2  Black Sea Sprat  00003.png
# 3  Black Sea Sprat  00004.png
# 4  Black Sea Sprat  00005.png

# %%
fish_mask_df.head()
# Out:
#                    fish  file_name
# 0  Black Sea Sprat mask  00001.png
# 1  Black Sea Sprat mask  00002.png
# 2  Black Sea Sprat mask  00003.png
# 3  Black Sea Sprat mask  00004.png
# 4  Black Sea Sprat mask  00005.png

# %%
#show the number of images for each fish species
fish_df["fish"].value_counts()
# Out:
# fish
# Black Sea Sprat       1000
# Gilt-Head Bream       1000
# Hourse Mackerel       1000
# Red Mullet            1000
# Red Sea Bream         1000
# Sea Bass              1000
# Shrimp                1000
# Striped Red Mullet    1000
# Trout                 1000
# Name: count, dtype: int64

# %%
fish_mask_df["fish"].value_counts()
# Out:
# fish
# Black Sea Sprat mask       1000
# Gilt-Head Bream mask       1000
# Hourse Mackerel mask       1000
# Red Mullet mask            1000
# Red Sea Bream mask         1000
# Sea Bass mask              1000
# Shrimp mask                1000
# Striped Red Mullet mask    1000
# Trout mask                 1000
# Name: count, dtype: int64

# %%
#show the number of images for each fish species
fish_df["fish"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='fish'>

# %%
#show the number of masks for each fish species
fish_mask_df["fish"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='fish'>

# %%
#combine fish_df and fish_mask_df
fish_df["mask_file_name"] = None
for fish in fish_species.keys():
    mask_files = fish_mask_df[fish_mask_df["fish"] == f"{fish} mask"]["file_name"]
    fish_df.loc[fish_df["fish"] == fish, "mask_file_name"] = mask_files.values
fish_df.head()
# Out:
#               fish  file_name mask_file_name
# 0  Black Sea Sprat  00001.png      00001.png
# 1  Black Sea Sprat  00002.png      00002.png
# 2  Black Sea Sprat  00003.png      00003.png
# 3  Black Sea Sprat  00004.png      00004.png
# 4  Black Sea Sprat  00005.png      00005.png

# %%
#train test split
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(fish_df, test_size=0.2, random_state=42)
train_df.head()
# Out:
#                     fish  file_name mask_file_name
# 6317              Shrimp  00318.png      00318.png
# 740      Black Sea Sprat  00741.png      00741.png
# 3781          Red Mullet  00782.png      00782.png
# 7850  Striped Red Mullet  00851.png      00851.png
# 2963     Hourse Mackerel  00964.png      00964.png

# %%
#train the model using pytorch
import torch
import torchvision
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import copy

# %%
# Define the model architecture
model = models.resnet18(pretrained=True)
num_ftrs = model.fc.in_features
# Here the size of each output sample is set to 9.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model.fc = nn.Linear(num_ftrs, 9)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)
# Out:
# c:\Users\Mihu\anaconda\envs\mondre\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Mihu\anaconda\envs\mondre\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Create data loaders for training and validation datasets

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
train_dataset = datasets.ImageFolder(data_dir, data_transforms['train'])
val_dataset = datasets.ImageFolder(data_dir, data_transforms['val'])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Train the model for multiple epochs
num_epochs = 10
best_model_wts = copy.deepcopy(model.state_dict())
best_acc = 0.0

for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}/{num_epochs}')
    print('-' * 10)

    # Training phase
    model.train()
    running_loss = 0.0
    running_corrects = 0

    for inputs, labels in train_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        with torch.set_grad_enabled(True):
            outputs = model(inputs.to(device))  # Ensure inputs are on the same device as the model
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_dataset)
    epoch_acc = running_corrects.double() / len(train_dataset)

    print(f'Train Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    # Validation phase
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    for inputs, labels in val_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        with torch.set_grad_enabled(False):
            outputs = model(inputs.to(device))  # Ensure inputs are on the same device as the model
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(val_dataset)
    epoch_acc = running_corrects.double() / len(val_dataset)

    print(f'Val Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    # Save the best model
    if epoch_acc > best_acc:
        best_acc = epoch_acc
        best_model_wts = copy.deepcopy(model.state_dict())
# Out:
# Epoch 1/10
# ----------
# Train Loss: 1.6472 Acc: 0.4668
# Val Loss: 0.9278 Acc: 0.7677
# Epoch 2/10
# ----------
# Train Loss: 1.0217 Acc: 0.6894
# Val Loss: 0.5789 Acc: 0.8341
# Epoch 3/10
# ----------
# Train Loss: 0.8135 Acc: 0.7350
# Val Loss: 0.4329 Acc: 0.8793
# Epoch 4/10
# ----------
# Train Loss: 0.7039 Acc: 0.7620
# Val Loss: 0.3503 Acc: 0.8893
# Epoch 5/10
# ----------
# Train Loss: 0.6468 Acc: 0.7742
# Val Loss: 0.2980 Acc: 0.9026
# Epoch 6/10
# ----------
# Train Loss: 0.6002 Acc: 0.7911
# Val Loss: 0.2643 Acc: 0.9114
# Epoch 7/10
# ----------
# Train Loss: 0.5596 Acc: 0.8040
# Val Loss: 0.2396 Acc: 0.9215
# Epoch 8/10
# ----------
# Train Loss: 0.5409 Acc: 0.8082
# Val Loss: 0.2162 Acc: 0.9260
# Epoch 9/10
# ----------
# Train Loss: 0.5157 Acc: 0.8159
# Val Loss: 0.1931 Acc: 0.9363
# Epoch 10/10
# ----------
# Train Loss: 0.5038 Acc: 0.8212
# Val Loss: 0.1838 Acc: 0.9367
